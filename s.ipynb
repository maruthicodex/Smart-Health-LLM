# %%
import os

IGNORE = {"venv", ".git", "__pycache__", "myenv"}  # folders to skip

def print_dir_tree(root_dir, prefix=""):
    entries = [e for e in os.listdir(root_dir) if e not in IGNORE]
    for i, item in enumerate(entries):
        path = os.path.join(root_dir, item)
        connector = "└── " if i == len(entries) - 1 else "├── "
        print(prefix + connector + item)
        if os.path.isdir(path):
            extension = "    " if i == len(entries) - 1 else "│   "
            print_dir_tree(path, prefix + extension)

# Example usage
project_root = "/home/ml/Documents/SmartHealth-LLM"
print_dir_tree(project_root)
# Out:
# ├── venv
# │   ├── pyvenv.cfg
# │   ├── lib64
# │   │   └── python3.9
# │   │       └── site-packages
# │   │           ├── thinc
# │   │           │   ├── shims
# │   │           │   │   ├── tensorflow.py
# │   │           │   │   ├── __pycache__
# │   │           │   │   │   ├── tensorflow.cpython-39.pyc
# │   │           │   │   │   ├── pytorch_grad_scaler.cpython-39.pyc
# │   │           │   │   │   ├── shim.cpython-39.pyc
# │   │           │   │   │   ├── pytorch.cpython-39.pyc
# │   │           │   │   │   ├── mxnet.cpython-39.pyc
# │   │           │   │   │   ├── __init__.cpython-39.pyc
# │   │           │   │   │   └── torchscript.cpython-39.pyc
# │   │           │   │   ├── __init__.py
# │   │           │   │   ├── shim.py
# │   │           │   │   ├── pytorch.py
# │   │           │   │   ├── pytorch_grad_scaler.py
# │   │           │   │   ├── torchscript.py
# │   │           │   │   └── mxnet.py
# │   │           │   ├── config.py
# │   │           │   ├── layers
# ...
